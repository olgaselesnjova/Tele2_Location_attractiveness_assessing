# %% [markdown]
# ## Data Preprocessing and Exploratory Data Analisys
# ### Tele2 - Location attractiveness assessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import plotly.graph_objects as go

from matplotlib import pyplot as plt

# %%
hex_data = pd.read_csv('~/__TELE2LAA/spb_hex.csv', sep = ',', decimal = ',', index_col = 0) 
hex = pd.DataFrame(hex_data)

# %%
tracks_data = pd.read_csv('~/__TELE2LAA/tracks_v2.csv', sep = ';', decimal = ',', index_col = 0) 
tracks = pd.DataFrame(tracks_data)

# %%
hex.head()
# Out:
#               h3_9  age_20  age_20_30  age_30_40  age_40_60  age_60  male  \
# 0  8911063244fffff       0          0          8          3       1     7
# 1  891106074d7ffff       0         13          3          2       1     4
# 2  8911062a87bffff       0          0          1          0       0     1
# 3  89110615e0fffff       0          2         11         20      15    46
# 4  892d721010bffff       0          0          2          1       1     3
#
#    female  car_owners  carsharing_user  not_citizen_rf  public_trnsprt_user  \
# 0       5           4                5               2                    0
# 1      17          16                1              17                    0
# 2       0           1                1               0                    0
# 3      19          14                0              22                    1
# 4       1           0                0               0                    0
#
# ...

# %%
tracks.head()
# Out:
#              id        start_dttm          end_dttm             h3_9
# 0  9.363030e+11  12.03.2023 23:31  13.03.2023 13:41  891106a1cd3ffff
# 1  9.363030e+11  13.03.2023 17:04  13.03.2023 20:06  891106a11c3ffff
# 2  9.363030e+11  08.03.2023 21:25   09.03.2023 9:31  891106a1cd3ffff
# 3  9.363030e+11   09.03.2023 9:31  09.03.2023 21:38  891106a1cd3ffff
# 4  9.363030e+11  10.03.2023 21:35  10.03.2023 23:05  891106a11bbffff

# %%
merged = pd.merge(hex, tracks, on='h3_9')

# %%
merged
# Out:
#                     h3_9  age_20  age_20_30  age_30_40  age_40_60  age_60  \
# 0        8911063244fffff       0          0          8          3       1
# 1        8911063244fffff       0          0          8          3       1
# 2        8911063244fffff       0          0          8          3       1
# 3        8911063244fffff       0          0          8          3       1
# 4        8911063244fffff       0          0          8          3       1
# ...                  ...     ...        ...        ...        ...     ...
# 1048570  891160c0693ffff       0          0          0          0       2
# 1048571  8910a810153ffff       0          0          1          1       0
# 1048572  8910a810153ffff       0          0          1          1       0
# 1048573  8910120f67bffff       0          2          0          0       0
# 1048574  8910120f67bffff       0          2          0          0       0
#
#          male  female  car_owners  carsharing_user  ...  public_trnsprt_user  \
# ...

# %%
merged.describe()
# Out:
#              age_20     age_20_30     age_30_40     age_40_60        age_60  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   4.637464e+00  5.116832e+01  1.306554e+02  1.779317e+02  6.710536e+01
# std    1.387204e+01  5.781563e+01  1.191615e+02  1.519667e+02  6.959130e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  6.000000e+00  3.400000e+01  5.400000e+01  1.200000e+01
# 50%    0.000000e+00  3.300000e+01  1.030000e+02  1.460000e+02  4.600000e+01
# 75%    1.000000e+00  7.900000e+01  1.950000e+02  2.680000e+02  1.040000e+02
# max    1.540000e+02  3.770000e+02  6.460000e+02  7.200000e+02  4.280000e+02
#
#                male        female    car_owners  carsharing_user  \
# count  1.048575e+06  1.048575e+06  1.048575e+06     1.048575e+06
# mean   2.627592e+02  2.038336e+02  1.642032e+02     6.006433e+01
# std    2.165587e+02  1.729298e+02  1.423101e+02     6.466134e+01
# ...

# %%
merged.info()
#(merged.isna().sum() / len(merged)).rename('percent of NA').to_frame().style.bar(vmax=1, vmin=0).format('{:.2%}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   h3_9                 1048575 non-null  object
#  1   age_20               1048575 non-null  int64
#  2   age_20_30            1048575 non-null  int64
#  3   age_30_40            1048575 non-null  int64
#  4   age_40_60            1048575 non-null  int64
#  5   age_60               1048575 non-null  int64
#  6   male                 1048575 non-null  int64
#  7   female               1048575 non-null  int64
#  8   car_owners           1048575 non-null  int64
#  9   carsharing_user      1048575 non-null  int64
#  10  not_citizen_rf       1048575 non-null  int64
#  11  public_trnsprt_user  1048575 non-null  int64
#  12  healthy_food_inter   1048575 non-null  int64
#  13  salary_1             1048575 non-null  int64
# ...

# %%
#histograms = merged.iloc[:,:5].hist(figsize=(20,10))
